# %%
import numpy as np

# %%
p_pred = np.array([[0.1, 0.6, 0.2, 0.1], [0.1, 0.6, 0.2, 0.1]])
print(p_pred.shape)
# Out:
# (2, 4)

# %%
max_ = np.argmax(p_pred, axis=1)

# %%
print(max_)
# Out:
# [1 1]

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 decisions = np.argmax(p_pred, axis=1).reshape((len(p_pred[0]), len(p_pred[0])))
#
# ValueError: cannot reshape array of size 2 into shape (4,4)

# %%
print(decisions)
# Out:
# [[1]]
