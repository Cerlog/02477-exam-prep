# %%
# %matplotlib inline
import pylab as plt
import pandas as pd
import jax.numpy as jnp
from jax import random
import seaborn as snb

# %%
outcomes = jnp.array([
    [0.5, 0.2],
    [0.5, 0.3],
    [0.6, 0.1],
    [0.6, 0.2],
    [0.6, 0.3],
    [0.7, 0.1],
    [0.7, 0.2]
    
])

probabilities = jnp.array([0.12, 0.09, 0.12, 0.2, 0.12, 0.23, 0.12])


print(outcomes[:, 0])
# Out:
# [0.5 0.5 0.6 0.6 0.6 0.7 0.7]

# %%
print(jnp.sum(outcomes[:, 0] * probabilities))
# Out:
# 0.614

# %%
mean = jnp.sum(outcomes[:, 0] * probabilities)

# %%
variance = jnp.sum((outcomes[:, 0] - mean)**2 * probabilities)
# Out:
# 0.0054039992
